# %%
 import geopandas as gpd

# %%
file = "data/geospatial/Subwatersheds.geojson"
df = gpd.read_file(file)
df.head()
# Out:
#    OBJECTID          Maj_shed  Shape_STArea__  Shape_STLength__  Shape_Length  \
# 0         1    Christmas Lake    5.992375e+06      12660.670657   8964.585801
# 1         2        Dutch Lake    1.527072e+07      21369.293079  15113.897483
# 2         3  Gleason Lake Cre    2.247501e+07      33764.918405  23864.003889
# 3         4       Hadley Lake    8.025336e+06      16149.225938  11417.037033
# 4         5   Lake Minnetonka    2.627959e+08     130158.091897  92095.540814
#
#      Shape_Area                                           geometry
# 0  3.004847e+06  (POLYGON ((457762.6554554543 4972305.08239105,...
# 1  7.642238e+06  (POLYGON ((445490.7631416116 4979607.310046213...
# 2  1.123008e+07  (POLYGON ((460406.9082970861 4980930.791038431...
# 3  4.011442e+06  (POLYGON ((458810.5643314747 4981843.268408211...
# 4  1.315873e+08  (POLYGON ((452609.2880040435 4982971.031010844...
