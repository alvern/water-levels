# %% [markdown]
# # Lake Levels ETL
# ## Data Scraping, Munging
# ---

# %%
import pandas as pd

from sqlalchemy import create_engine
from sqlalchemy import Column, Date, Integer, String, Float, Table

# import schema from python file
from schema_lake_levels import Base
from schema_lake_levels import Lake_names, Lake_levels

# %%
# read in csv file
lake_id_df = pd.read_csv("data/water-level/lakes/MCWD_Lake_ID.csv")

lake_id_df.head()
# Out:
#   LAKE_NAME   LAKE_ID   latitude  longitude
# 0  Hiawatha  27001800  44.921034 -93.236141
# 1    Mother  27002300  44.893298 -93.241013
# 2   Nokomis  27001900  44.908634 -93.242187
# 3      Taft  27068300  44.892951 -93.249752
# 4    Legion  27002400  44.885760 -93.262240

# %%
# make col names lowercase
lake_id_df.columns = ['name', 'id', 'lat', 'lng']

# drop duplicate ids
lake_id_df.drop_duplicates(subset='id', inplace=True)

# set 'lake_id' as index
lake_id_df.set_index('id', inplace=True)

# preview
lake_id_df.head()
# Out:
#               name        lat        lng
# id
# 27001800  Hiawatha  44.921034 -93.236141
# 27002300    Mother  44.893298 -93.241013
# 27001900   Nokomis  44.908634 -93.242187
# 27068300      Taft  44.892951 -93.249752
# 27002400    Legion  44.885760 -93.262240

# %%
# function to convert all lake data (df) for a given lake id into dict format
def lake_to_dict(lake_id, df):

    # grab all measurements for lake
    elevations = list(df.loc[df.id == lake_id].elevation)
    read_dates = list(df.loc[df.id == lake_id].read_date)
    datum_adjs = list(df.loc[df.id == lake_id].datum_adj)
    
    measurements = list(zip(elevations, read_dates, datum_adjs))

    measurement_keys = ['elevation', 'read_date', 'datum_adj']
    
    # make measurements json format
    measurements_json = []
    for i in range(len(measurements)):
        measurement_dict = dict(zip(measurement_keys, measurements[i]))
        measurements_json.append(measurement_dict)

    # create lake_dict using measurements_json
    lake_dict = {
        'name': lake_id_df['name'][lake_id],
        'id': lake_id,
        'location': {
            'lat': lake_id_df['lat'][lake_id],
            'lng': lake_id_df['lng'][lake_id]
        },
        'measurements': measurements_json
    }
    
    return lake_dict

# %%
# base url for scraping lake-level data
base_url = "https://files.dnr.state.mn.us/cgi-bin/lk_levels_dump.pl?format=csv&id="

# variable to track progress of loop
lake_count = 0

# store ids for lakes that failed and succeeded to be inserted
failed = []
successful = []

# list to store all dfs read-in to concatenate later
df_list = []

# loop through index of lake_id_df (lake ids are the index)
for lake_id in lake_id_df.index:
    
    lake_count += 1
    print(f"Getting data for lake {lake_count} of {len(lake_id_df.index)}.......")
    print(f"Lake id: {lake_id}.........")
    
    
    try:
        # read data from url into df
        df = pd.read_csv(f"{base_url}{lake_id}")

        # change column names to lowercase
        df.columns = map(str.lower, df.columns)

        # rename 'chr_id' to 'id'
        df.rename(columns={"chr_id": "id"}, inplace=True)

        # drop duplicate date entries
        df.drop_duplicates(subset='read_date', inplace=True)
        
        if len(df['id']) >= 10:
            
            df_list.append(df.copy())

        print("........................Success")
        print("------------------------------------------------------------------\n\n")
        successful.append(lake_id)
        
    except:
        print(".......................Process failed")
        print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx\n\n")
        failed.append(lake_id)
# Out:
# Getting data for lake 1 of 141.......
# Lake id: 27001800.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 2 of 141.......
# Lake id: 27002300.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 3 of 141.......
# Lake id: 27001900.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 4 of 141.......
# Lake id: 27068300.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 5 of 141.......
# Lake id: 27002400.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 6 of 141.......
# Lake id: 27002200.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 7 of 141.......
# Lake id: 27068400.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 8 of 141.......
# Lake id: 27068500.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 9 of 141.......
# Lake id: 27001600.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 10 of 141.......
# Lake id: 27001700.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 11 of 141.......
# Lake id: 27004000.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 12 of 141.......
# Lake id: 27003100.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 13 of 141.......
# Lake id: 27003900.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 14 of 141.......
# Lake id: 27003800.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 15 of 141.......
# Lake id: 27067500.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 16 of 141.......
# Lake id: 27001500.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 17 of 141.......
# Lake id: 27065600.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 18 of 141.......
# Lake id: 27066400.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 19 of 141.......
# Lake id: 27004100.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 20 of 141.......
# Lake id: 27067000.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 21 of 141.......
# Lake id: 27066900.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 22 of 141.......
# Lake id: 27005400.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 23 of 141.......
# Lake id: 27066100.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 24 of 141.......
# Lake id: 27071000.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 25 of 141.......
# Lake id: 27005100.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 26 of 141.......
# Lake id: 27077900.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 27 of 141.......
# Lake id: 27071400.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 28 of 141.......
# Lake id: 27005300.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 29 of 141.......
# Lake id: 27005200.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 30 of 141.......
# Lake id: 27071300.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 31 of 141.......
# Lake id: 27008400.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 32 of 141.......
# Lake id: 27008200.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 33 of 141.......
# Lake id: 27077100.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 34 of 141.......
# Lake id: 27075100.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 35 of 141.......
# Lake id: 27075000.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 36 of 141.......
# Lake id: 27074700.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 37 of 141.......
# Lake id: 27073900.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 38 of 141.......
# Lake id: 27013300.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 39 of 141.......
# Lake id: 27074600.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 40 of 141.......
# Lake id: 27068701.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 41 of 141.......
# Lake id: 27013301.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 42 of 141.......
# Lake id: 27008500.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 43 of 141.......
# Lake id: 99001038.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 44 of 141.......
# Lake id: 27009500.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 45 of 141.......
# Lake id: 27010800.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 46 of 141.......
# Lake id: 27046800.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 47 of 141.......
# Lake id: 27008600.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 48 of 141.......
# Lake id: 27082200.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 49 of 141.......
# Lake id: 27082400.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 50 of 141.......
# Lake id: 27013302.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 51 of 141.......
# Lake id: 27010900.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 52 of 141.......
# Lake id: 27008700.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 53 of 141.......
# Lake id: 27087000.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 54 of 141.......
# Lake id: 27013400.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 55 of 141.......
# Lake id: 27013303.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 56 of 141.......
# Lake id: 27087600.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 57 of 141.......
# Lake id: 27015800.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 58 of 141.......
# Lake id: 27015900.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 59 of 141.......
# Lake id: 27013800.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 60 of 141.......
# Lake id: 27087700.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 61 of 141.......
# Lake id: 27014200.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 62 of 141.......
# Lake id: 27013304.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 63 of 141.......
# Lake id: 27016000.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 64 of 141.......
# Lake id: 27014100.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 65 of 141.......
# Lake id: 27014400.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 66 of 141.......
# Lake id: 27089600.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 67 of 141.......
# Lake id: 27015700.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 68 of 141.......
# Lake id: 27089800.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 69 of 141.......
# Lake id: 27016100.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 70 of 141.......
# Lake id: 27014300.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 71 of 141.......
# Lake id: 27014000.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 72 of 141.......
# Lake id: 27090000.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 73 of 141.......
# Lake id: 27015600.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 74 of 141.......
# Lake id: 27015500.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 75 of 141.......
# Lake id: 27090800.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 76 of 141.......
# Lake id: 27015000.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 77 of 141.......
# Lake id: 27015100.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 78 of 141.......
# Lake id: 27013310.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 79 of 141.......
# Lake id: 27091200.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 80 of 141.......
# Lake id: 27013305.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 81 of 141.......
# Lake id: 27013311.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 82 of 141.......
# Lake id: 27016200.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 83 of 141.......
# Lake id: 10000900.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 84 of 141.......
# Lake id: 99001005.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 85 of 141.......
# Lake id: 27013312.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 86 of 141.......
# Lake id: 27051800.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 87 of 141.......
# Lake id: 27013313.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 88 of 141.......
# Lake id: 27052200.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 89 of 141.......
# Lake id: 10020600.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 90 of 141.......
# Lake id: 10001100.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 91 of 141.......
# Lake id: 27015400.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 92 of 141.......
# Lake id: 10001500.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 93 of 141.......
# Lake id: 27013900.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 94 of 141.......
# Lake id: 10001000.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 95 of 141.......
# Lake id: 27013306.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 96 of 141.......
# Lake id: 27096500.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 97 of 141.......
# Lake id: 27094500.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 98 of 141.......
# Lake id: 27040800.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 99 of 141.......
# Lake id: 99000999.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 100 of 141.......
# Lake id: 10001800.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 101 of 141.......
# Lake id: 27094800.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 102 of 141.......
# Lake id: 27013315.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 103 of 141.......
# Lake id: 27013314.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 104 of 141.......
# Lake id: 27094700.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 105 of 141.......
# Lake id: 10004500.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 106 of 141.......
# Lake id: 10004100.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 107 of 141.......
# Lake id: 10020001.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 108 of 141.......
# Lake id: 10004600.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 109 of 141.......
# Lake id: 10020002.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 110 of 141.......
# Lake id: 10004700.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 111 of 141.......
# Lake id: 10004800.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 112 of 141.......
# Lake id: 27018200.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 113 of 141.......
# Lake id: 10005600.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 114 of 141.......
# Lake id: 10005400.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 115 of 141.......
# Lake id: 10004400.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 116 of 141.......
# Lake id: 27109600.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 117 of 141.......
# Lake id: 27018100.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 118 of 141.......
# Lake id: 10013400.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 119 of 141.......
# Lake id: 27095200.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 120 of 141.......
# Lake id: 10013500.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 121 of 141.......
# Lake id: 10005000.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 122 of 141.......
# Lake id: 27013309.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 123 of 141.......
# Lake id: 27018500.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 124 of 141.......
# Lake id: 10004401.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 125 of 141.......
# Lake id: 10005300.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 126 of 141.......
# Lake id: 10013800.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 127 of 141.......
# Lake id: 10019100.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 128 of 141.......
# Lake id: 27018300.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 129 of 141.......
# Lake id: 10004900.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 130 of 141.......
# Lake id: 10013900.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 131 of 141.......
# Lake id: 27095800.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 132 of 141.......
# Lake id: 27093900.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 133 of 141.......
# Lake id: 27095700.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 134 of 141.......
# Lake id: 10014000.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 135 of 141.......
# Lake id: 10004300.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 136 of 141.......
# Lake id: 10014100.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 137 of 141.......
# Lake id: 10005100.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 138 of 141.......
# Lake id: 10004200.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 139 of 141.......
# Lake id: 10019000.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 140 of 141.......
# Lake id: 27018600.........
# ........................Success
# ------------------------------------------------------------------
#
#
# Getting data for lake 141 of 141.......
# Lake id: 10014300.........
# ........................Success
# ------------------------------------------------------------------

# %%
# concatenate data retrieved into new df
lake_levels_df = pd.concat(df_list)
lake_levels_df.head()
# Out:
#          id  elevation   read_date datum_adj
# 0  27001800     811.40  1926-04-15   NGVD 29
# 1  27001800     815.35  1926-08-05   NGVD 29
# 2  27001800     812.72  1927-03-29   NGVD 29
# 3  27001800     813.04  1927-11-30   NGVD 29
# 4  27001800     814.50  1928-04-12   NGVD 29

# %%
# remove all data for lakes with less than 10 records

# empty list for storing ids of dropped lakes
dropped = []

print("Dropping lakes with fewer then 10 measurements....")
for lake_id in lake_id_df.index:
    
    # drop lakes with less than 10 measurements
    if len(lake_levels_df.loc[lake_levels_df['id'] == lake_id]['id']) < 10:
        lake_levels_df.drop(lake_levels_df[lake_levels_df['id'] == lake_id].index, inplace=True)
        dropped.append(lake_id)

print(f"Number of laked dropped: {len(dropped)}.")

# reset index
lake_levels_df = lake_levels_df.reset_index(drop=True)
lake_levels_df.head()
# Out:
# Dropping lakes with fewer then 10 measurements....
# Number of laked dropped: 100.
#          id  elevation   read_date datum_adj
# 0  27001800     811.40  1926-04-15   NGVD 29
# 1  27001800     815.35  1926-08-05   NGVD 29
# 2  27001800     812.72  1927-03-29   NGVD 29
# 3  27001800     813.04  1927-11-30   NGVD 29
# 4  27001800     814.50  1928-04-12   NGVD 29

# %%
# write dataframes to csv's
lake_levels_df.to_csv("resources/scraped_lake_measurements.csv", index=False)
lake_id_df.to_csv("resources/lake_info_transformed.csv", index=True)

# %%
# format all lake data as JSON

# list of included lake_ids to iterate through
lake_id_list = lake_levels_df.groupby('id').all().index

# empty list for json format
lakes_json = []

# loop through included lake_ids
for lake_id in lake_id_list:
    lake_dict = lake_to_dict(lake_id, lake_levels_df)
    lakes_json.append(lake_dict)

# %%
# create list of lake names
lake_list = []

for id in lake_id_list:
    lake_list.append(lake_id_df['name'][id])

# %%
lake_dict = {}

for i in range(len(lake_list)):
    lake_dict[lake_list[i]] = lakes_json[i]

# %%
lake_dict['Nokomis']
# Out:
# {'name': 'Nokomis',
#  'id': 27001900,
#  'location': {'lat': 44.90863394, 'lng': -93.24218679},
#  'measurements': [{'elevation': 816.7,
#    'read_date': '1906-01-01',
#    'datum_adj': 'NGVD 29'},
#   {'elevation': 815.4, 'read_date': '1907-01-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.4, 'read_date': '1914-01-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.1, 'read_date': '1915-01-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.6, 'read_date': '1918-01-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.4, 'read_date': '1919-01-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.0, 'read_date': '1921-01-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.1, 'read_date': '1922-01-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.1, 'read_date': '1923-01-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.9, 'read_date': '1924-01-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.96, 'read_date': '1925-03-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.0, 'read_date': '1926-04-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.12, 'read_date': '1926-08-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.31, 'read_date': '1927-03-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.97, 'read_date': '1927-11-30', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.27, 'read_date': '1928-03-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.04, 'read_date': '1928-04-12', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.01, 'read_date': '1928-11-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.13, 'read_date': '1929-04-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.79, 'read_date': '1929-11-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.33, 'read_date': '1930-04-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.96, 'read_date': '1930-08-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.77, 'read_date': '1930-11-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.17, 'read_date': '1931-04-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.91, 'read_date': '1931-05-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.95, 'read_date': '1931-05-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.03, 'read_date': '1931-05-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.07, 'read_date': '1931-05-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.18, 'read_date': '1931-05-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.15, 'read_date': '1931-05-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.12, 'read_date': '1931-05-25', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.25, 'read_date': '1931-05-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.25, 'read_date': '1931-06-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.36, 'read_date': '1931-06-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.39, 'read_date': '1931-06-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.45, 'read_date': '1931-06-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.66, 'read_date': '1931-06-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.66, 'read_date': '1931-06-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.5, 'read_date': '1931-06-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.27, 'read_date': '1931-07-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.05, 'read_date': '1931-07-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.86, 'read_date': '1931-07-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.63, 'read_date': '1931-07-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.44, 'read_date': '1931-08-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.37, 'read_date': '1931-08-10', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.29, 'read_date': '1931-08-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.14, 'read_date': '1931-08-31', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.02, 'read_date': '1931-09-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 810.89, 'read_date': '1931-09-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 810.92, 'read_date': '1931-09-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 810.93, 'read_date': '1931-10-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 810.81, 'read_date': '1931-10-12', 'datum_adj': 'NGVD 29'},
#   {'elevation': 810.71, 'read_date': '1931-11-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 810.82, 'read_date': '1931-11-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.6, 'read_date': '1932-04-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.43, 'read_date': '1932-06-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.06, 'read_date': '1932-07-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 809.67, 'read_date': '1932-11-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 809.9, 'read_date': '1932-12-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 809.91, 'read_date': '1933-01-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 810.41, 'read_date': '1933-01-31', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.0, 'read_date': '1933-02-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.61, 'read_date': '1933-02-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.33, 'read_date': '1933-03-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.89, 'read_date': '1933-03-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.83, 'read_date': '1933-04-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.09, 'read_date': '1933-04-25', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.57, 'read_date': '1933-05-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.87, 'read_date': '1933-06-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.04, 'read_date': '1933-08-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.3, 'read_date': '1933-09-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.85, 'read_date': '1933-10-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.55, 'read_date': '1933-11-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.4, 'read_date': '1933-11-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 810.97, 'read_date': '1934-02-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.48, 'read_date': '1934-02-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.94, 'read_date': '1934-03-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.14, 'read_date': '1934-04-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.29, 'read_date': '1934-04-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.89, 'read_date': '1934-04-30', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.78, 'read_date': '1934-06-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.84, 'read_date': '1934-06-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.05, 'read_date': '1934-07-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.34, 'read_date': '1934-08-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.67, 'read_date': '1934-09-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.58, 'read_date': '1934-10-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.91, 'read_date': '1934-10-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.84, 'read_date': '1934-11-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.85, 'read_date': '1934-12-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.07, 'read_date': '1935-03-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.63, 'read_date': '1935-03-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.06, 'read_date': '1935-04-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.52, 'read_date': '1935-04-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.24, 'read_date': '1935-04-30', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.93, 'read_date': '1935-05-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.58, 'read_date': '1935-06-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.91, 'read_date': '1935-07-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.2, 'read_date': '1935-08-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.6, 'read_date': '1935-08-31', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.08, 'read_date': '1935-10-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.01, 'read_date': '1935-11-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.88, 'read_date': '1935-12-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.59, 'read_date': '1936-02-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.5, 'read_date': '1936-03-31', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.04, 'read_date': '1936-05-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.56, 'read_date': '1936-06-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.04, 'read_date': '1936-07-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.72, 'read_date': '1936-07-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.97, 'read_date': '1936-08-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.53, 'read_date': '1936-09-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.73, 'read_date': '1936-10-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.3, 'read_date': '1936-11-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.1, 'read_date': '1936-12-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.43, 'read_date': '1937-04-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.17, 'read_date': '1937-05-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.71, 'read_date': '1937-06-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.27, 'read_date': '1937-08-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.54, 'read_date': '1937-09-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.2, 'read_date': '1937-12-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 810.86, 'read_date': '1938-02-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.84, 'read_date': '1938-03-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1938-05-31', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.5, 'read_date': '1938-07-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.02, 'read_date': '1938-08-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.95, 'read_date': '1938-10-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.41, 'read_date': '1939-12-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.82, 'read_date': '1940-04-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.99, 'read_date': '1940-10-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.23, 'read_date': '1940-12-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.26, 'read_date': '1941-04-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.9, 'read_date': '1941-11-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.85, 'read_date': '1942-03-30', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1942-11-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.1, 'read_date': '1943-03-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.13, 'read_date': '1943-04-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1943-05-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.08, 'read_date': '1943-05-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.08, 'read_date': '1943-05-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.15, 'read_date': '1943-06-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1943-06-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.7, 'read_date': '1943-06-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.46, 'read_date': '1943-06-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.16, 'read_date': '1943-06-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.08, 'read_date': '1943-06-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1943-06-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.98, 'read_date': '1943-06-30', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.04, 'read_date': '1943-07-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1943-07-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1943-07-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.02, 'read_date': '1943-07-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1943-08-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1943-09-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.8, 'read_date': '1943-10-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.05, 'read_date': '1943-11-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1944-04-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1944-04-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.2, 'read_date': '1944-05-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.5, 'read_date': '1944-06-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.6, 'read_date': '1944-07-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1944-08-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.1, 'read_date': '1944-09-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1944-10-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.1, 'read_date': '1944-11-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.15, 'read_date': '1945-03-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.05, 'read_date': '1945-04-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.1, 'read_date': '1945-05-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.1, 'read_date': '1945-06-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1945-07-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.1, 'read_date': '1945-08-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1945-09-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.6, 'read_date': '1945-10-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.05, 'read_date': '1945-11-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.09, 'read_date': '1945-11-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.05, 'read_date': '1946-03-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.02, 'read_date': '1946-03-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1946-04-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.8, 'read_date': '1946-05-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1946-06-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1946-07-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.5, 'read_date': '1946-08-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.8, 'read_date': '1946-09-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.5, 'read_date': '1946-10-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.9, 'read_date': '1946-11-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.06, 'read_date': '1946-11-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1947-04-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1947-04-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.05, 'read_date': '1947-05-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1947-06-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1947-07-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.6, 'read_date': '1947-08-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.3, 'read_date': '1947-09-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.5, 'read_date': '1947-10-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.5, 'read_date': '1947-11-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.64, 'read_date': '1947-11-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.24, 'read_date': '1948-04-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.2, 'read_date': '1948-07-12', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.9, 'read_date': '1948-07-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.9, 'read_date': '1948-08-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.8, 'read_date': '1948-10-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.05, 'read_date': '1948-11-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.7, 'read_date': '1949-03-25', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.33, 'read_date': '1949-04-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1949-04-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1949-04-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.4, 'read_date': '1949-05-30', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.3, 'read_date': '1949-06-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.1, 'read_date': '1949-07-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.0, 'read_date': '1949-07-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.15, 'read_date': '1949-07-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.95, 'read_date': '1949-08-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.81, 'read_date': '1949-12-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.09, 'read_date': '1950-04-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1950-05-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1950-05-25', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.05, 'read_date': '1950-07-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.3, 'read_date': '1950-08-23', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.84, 'read_date': '1950-10-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.73, 'read_date': '1951-05-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1951-07-10', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.12, 'read_date': '1951-07-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.25, 'read_date': '1951-09-12', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.44, 'read_date': '1951-09-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.29, 'read_date': '1951-10-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.12, 'read_date': '1951-11-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.5, 'read_date': '1952-04-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.22, 'read_date': '1952-04-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.08, 'read_date': '1952-04-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.85, 'read_date': '1952-04-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.13, 'read_date': '1952-05-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.54, 'read_date': '1952-05-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.24, 'read_date': '1952-05-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.17, 'read_date': '1952-06-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.17, 'read_date': '1952-06-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.08, 'read_date': '1952-07-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.01, 'read_date': '1952-08-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.58, 'read_date': '1952-09-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.58, 'read_date': '1952-09-25', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.13, 'read_date': '1952-10-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.76, 'read_date': '1953-03-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.25, 'read_date': '1953-04-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.55, 'read_date': '1953-05-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.58, 'read_date': '1953-06-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.97, 'read_date': '1953-06-25', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.63, 'read_date': '1953-06-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.08, 'read_date': '1953-07-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.75, 'read_date': '1953-07-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.45, 'read_date': '1953-07-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.36, 'read_date': '1953-07-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.67, 'read_date': '1953-08-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.75, 'read_date': '1953-09-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.45, 'read_date': '1953-10-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.08, 'read_date': '1953-11-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.04, 'read_date': '1953-11-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.78, 'read_date': '1954-04-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.1, 'read_date': '1954-04-30', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.02, 'read_date': '1954-05-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1954-05-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.2, 'read_date': '1954-06-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.6, 'read_date': '1954-07-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.42, 'read_date': '1954-08-25', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.6, 'read_date': '1954-09-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.29, 'read_date': '1954-11-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.33, 'read_date': '1954-11-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.65, 'read_date': '1955-04-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.08, 'read_date': '1955-04-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.65, 'read_date': '1955-05-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.38, 'read_date': '1955-06-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.96, 'read_date': '1955-07-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.2, 'read_date': '1955-07-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.46, 'read_date': '1955-08-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.29, 'read_date': '1955-09-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.84, 'read_date': '1955-09-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.5, 'read_date': '1955-10-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.56, 'read_date': '1956-04-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.34, 'read_date': '1956-05-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.27, 'read_date': '1956-06-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.17, 'read_date': '1956-06-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.43, 'read_date': '1956-06-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.17, 'read_date': '1956-06-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.83, 'read_date': '1956-06-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.88, 'read_date': '1956-07-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.9, 'read_date': '1956-08-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.84, 'read_date': '1956-08-30', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.41, 'read_date': '1956-09-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.19, 'read_date': '1956-10-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.98, 'read_date': '1956-11-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.5, 'read_date': '1957-01-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.49, 'read_date': '1957-01-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.42, 'read_date': '1957-02-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.43, 'read_date': '1957-02-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.35, 'read_date': '1957-02-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.34, 'read_date': '1957-02-25', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.32, 'read_date': '1957-03-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.26, 'read_date': '1957-03-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.1, 'read_date': '1957-03-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.06, 'read_date': '1957-03-25', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.05, 'read_date': '1957-04-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.1, 'read_date': '1957-04-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.92, 'read_date': '1957-05-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.75, 'read_date': '1957-05-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.27, 'read_date': '1957-06-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.34, 'read_date': '1957-07-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.67, 'read_date': '1957-07-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.44, 'read_date': '1957-07-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.34, 'read_date': '1957-07-25', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.62, 'read_date': '1957-08-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.24, 'read_date': '1957-09-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.78, 'read_date': '1957-11-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.75, 'read_date': '1957-11-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.86, 'read_date': '1958-04-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.43, 'read_date': '1958-04-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.37, 'read_date': '1958-04-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.9, 'read_date': '1958-06-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.4, 'read_date': '1958-07-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.42, 'read_date': '1958-07-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.2, 'read_date': '1958-08-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.7, 'read_date': '1958-08-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.42, 'read_date': '1958-09-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.88, 'read_date': '1958-10-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.57, 'read_date': '1958-11-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.78, 'read_date': '1959-02-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.42, 'read_date': '1959-04-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.18, 'read_date': '1959-04-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.84, 'read_date': '1959-05-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.27, 'read_date': '1959-06-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.66, 'read_date': '1959-07-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.82, 'read_date': '1959-07-10', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.94, 'read_date': '1959-07-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.44, 'read_date': '1959-07-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.35, 'read_date': '1959-08-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.4, 'read_date': '1959-08-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.55, 'read_date': '1959-08-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.86, 'read_date': '1959-08-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.96, 'read_date': '1959-08-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.02, 'read_date': '1959-08-31', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.7, 'read_date': '1959-10-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.75, 'read_date': '1959-10-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.5, 'read_date': '1959-11-12', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.17, 'read_date': '1959-12-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.79, 'read_date': '1960-02-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.54, 'read_date': '1960-03-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.45, 'read_date': '1960-03-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.62, 'read_date': '1960-03-25', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.9, 'read_date': '1960-04-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.25, 'read_date': '1960-05-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.85, 'read_date': '1960-05-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.95, 'read_date': '1960-05-23', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.91, 'read_date': '1960-11-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.57, 'read_date': '1961-01-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.4, 'read_date': '1961-01-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.27, 'read_date': '1961-02-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.23, 'read_date': '1961-02-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.42, 'read_date': '1961-05-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.31, 'read_date': '1961-05-31', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.25, 'read_date': '1961-06-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.62, 'read_date': '1961-08-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.4, 'read_date': '1961-09-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.29, 'read_date': '1961-10-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.52, 'read_date': '1962-03-23', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.5, 'read_date': '1962-04-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.75, 'read_date': '1962-04-23', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.4, 'read_date': '1962-05-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.45, 'read_date': '1962-05-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.7, 'read_date': '1962-05-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.74, 'read_date': '1962-05-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.65, 'read_date': '1962-05-31', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.55, 'read_date': '1962-06-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.28, 'read_date': '1962-06-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.58, 'read_date': '1962-06-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.07, 'read_date': '1962-06-25', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.58, 'read_date': '1962-07-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.79, 'read_date': '1962-07-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.42, 'read_date': '1962-07-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.02, 'read_date': '1962-07-30', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.9, 'read_date': '1962-08-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.9, 'read_date': '1962-08-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.95, 'read_date': '1962-08-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.99, 'read_date': '1962-08-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.0, 'read_date': '1962-09-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.0, 'read_date': '1962-09-10', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.05, 'read_date': '1962-09-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.77, 'read_date': '1962-09-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.6, 'read_date': '1962-10-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.72, 'read_date': '1962-10-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.5, 'read_date': '1962-10-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1962-10-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.92, 'read_date': '1962-10-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.8, 'read_date': '1962-11-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.72, 'read_date': '1962-11-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.59, 'read_date': '1962-11-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.58, 'read_date': '1962-11-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.5, 'read_date': '1963-04-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.25, 'read_date': '1963-05-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.1, 'read_date': '1963-06-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.0, 'read_date': '1963-06-10', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.06, 'read_date': '1963-06-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.27, 'read_date': '1963-06-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.88, 'read_date': '1963-07-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.62, 'read_date': '1963-07-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.78, 'read_date': '1963-08-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.45, 'read_date': '1963-08-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.8, 'read_date': '1963-09-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.28, 'read_date': '1963-10-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.06, 'read_date': '1963-10-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.9, 'read_date': '1963-11-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.63, 'read_date': '1964-03-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.58, 'read_date': '1964-04-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.6, 'read_date': '1964-05-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.65, 'read_date': '1964-05-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.32, 'read_date': '1964-05-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.58, 'read_date': '1964-05-12', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.72, 'read_date': '1964-05-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.86, 'read_date': '1964-05-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.42, 'read_date': '1964-06-23', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.25, 'read_date': '1964-10-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.04, 'read_date': '1964-11-12', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.36, 'read_date': '1965-01-12', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.3, 'read_date': '1965-04-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.7, 'read_date': '1965-04-12', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.83, 'read_date': '1965-04-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.06, 'read_date': '1965-04-23', 'datum_adj': 'NGVD 29'},
#   {'elevation': 817.05, 'read_date': '1965-05-10', 'datum_adj': 'NGVD 29'},
#   {'elevation': 817.12, 'read_date': '1965-05-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 817.17, 'read_date': '1965-05-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 817.08, 'read_date': '1965-05-25', 'datum_adj': 'NGVD 29'},
#   {'elevation': 817.75, 'read_date': '1965-06-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 817.28, 'read_date': '1965-06-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.3, 'read_date': '1965-07-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.4, 'read_date': '1965-07-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.15, 'read_date': '1965-08-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.3, 'read_date': '1965-09-30', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1965-11-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.34, 'read_date': '1966-03-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.33, 'read_date': '1966-07-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.89, 'read_date': '1966-08-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.01, 'read_date': '1966-11-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.2, 'read_date': '1967-06-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.0, 'read_date': '1967-06-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.96, 'read_date': '1967-11-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.43, 'read_date': '1968-01-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.58, 'read_date': '1968-03-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.7, 'read_date': '1968-04-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.14, 'read_date': '1968-04-23', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.5, 'read_date': '1968-05-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.8, 'read_date': '1968-06-10', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.86, 'read_date': '1968-06-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.26, 'read_date': '1968-06-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.08, 'read_date': '1968-06-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.06, 'read_date': '1968-06-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.26, 'read_date': '1968-06-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.08, 'read_date': '1968-06-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.14, 'read_date': '1968-06-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.12, 'read_date': '1968-06-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1968-07-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.7, 'read_date': '1968-07-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.1, 'read_date': '1968-07-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.3, 'read_date': '1968-07-31', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.2, 'read_date': '1968-08-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.12, 'read_date': '1968-08-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.9, 'read_date': '1968-08-12', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.92, 'read_date': '1968-08-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.66, 'read_date': '1968-08-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.6, 'read_date': '1968-08-23', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.3, 'read_date': '1968-09-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.28, 'read_date': '1968-09-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.18, 'read_date': '1968-10-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.1, 'read_date': '1968-11-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.12, 'read_date': '1969-01-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.3, 'read_date': '1969-02-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.06, 'read_date': '1969-02-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.01, 'read_date': '1969-03-12', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.4, 'read_date': '1969-03-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.65, 'read_date': '1969-03-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.7, 'read_date': '1969-04-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.33, 'read_date': '1969-04-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.46, 'read_date': '1969-05-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.82, 'read_date': '1969-06-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.84, 'read_date': '1969-06-25', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.1, 'read_date': '1969-08-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.74, 'read_date': '1969-10-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.3, 'read_date': '1969-11-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.0, 'read_date': '1970-01-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.0, 'read_date': '1970-03-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.0, 'read_date': '1970-04-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.35, 'read_date': '1970-04-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.9, 'read_date': '1970-05-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.95, 'read_date': '1970-05-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.44, 'read_date': '1970-08-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.3, 'read_date': '1970-09-23', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.15, 'read_date': '1970-10-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.45, 'read_date': '1970-10-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.1, 'read_date': '1970-10-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.25, 'read_date': '1970-10-30', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.96, 'read_date': '1970-11-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1970-11-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.84, 'read_date': '1970-12-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.31, 'read_date': '1971-02-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.9, 'read_date': '1971-03-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.78, 'read_date': '1971-04-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.46, 'read_date': '1971-04-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.68, 'read_date': '1971-04-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.94, 'read_date': '1971-04-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.08, 'read_date': '1971-05-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.58, 'read_date': '1971-06-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.08, 'read_date': '1971-06-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.94, 'read_date': '1971-09-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.28, 'read_date': '1971-09-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.68, 'read_date': '1971-10-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.02, 'read_date': '1971-10-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.08, 'read_date': '1971-11-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.75, 'read_date': '1972-01-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.46, 'read_date': '1972-02-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.22, 'read_date': '1972-03-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.56, 'read_date': '1972-04-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.12, 'read_date': '1972-04-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.9, 'read_date': '1972-05-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.98, 'read_date': '1972-06-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.62, 'read_date': '1972-06-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.7, 'read_date': '1972-07-10', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.4, 'read_date': '1972-08-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.62, 'read_date': '1972-09-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.74, 'read_date': '1972-12-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.76, 'read_date': '1973-01-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.66, 'read_date': '1973-02-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.15, 'read_date': '1973-05-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.72, 'read_date': '1973-09-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.76, 'read_date': '1973-10-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.91, 'read_date': '1974-01-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1974-07-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.11, 'read_date': '1974-09-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.7, 'read_date': '1974-10-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.36, 'read_date': '1974-11-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.2, 'read_date': '1974-12-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.9, 'read_date': '1975-02-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.11, 'read_date': '1975-04-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.75, 'read_date': '1975-04-30', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.7, 'read_date': '1975-05-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.55, 'read_date': '1975-05-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.9, 'read_date': '1976-03-31', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.23, 'read_date': '1976-04-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.05, 'read_date': '1976-05-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.0, 'read_date': '1976-08-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.56, 'read_date': '1976-11-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.38, 'read_date': '1977-03-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.81, 'read_date': '1977-06-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.65, 'read_date': '1977-08-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.9, 'read_date': '1977-08-31', 'datum_adj': 'NGVD 29'},
#   {'elevation': 817.06, 'read_date': '1977-09-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.04, 'read_date': '1977-10-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.94, 'read_date': '1977-12-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.97, 'read_date': '1978-01-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.55, 'read_date': '1978-02-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.67, 'read_date': '1978-04-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.57, 'read_date': '1978-04-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.28, 'read_date': '1978-05-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.39, 'read_date': '1978-05-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.18, 'read_date': '1978-06-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.18, 'read_date': '1978-07-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.92, 'read_date': '1978-08-10', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.24, 'read_date': '1978-08-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.65, 'read_date': '1978-10-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.66, 'read_date': '1979-01-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.66, 'read_date': '1979-01-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.65, 'read_date': '1979-03-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.95, 'read_date': '1979-06-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.6, 'read_date': '1979-06-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.45, 'read_date': '1979-08-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.45, 'read_date': '1979-09-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.06, 'read_date': '1979-12-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.84, 'read_date': '1980-05-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.6, 'read_date': '1980-06-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.87, 'read_date': '1980-06-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.45, 'read_date': '1980-08-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.6, 'read_date': '1980-09-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.2, 'read_date': '1980-10-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.43, 'read_date': '1980-12-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.87, 'read_date': '1981-03-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.1, 'read_date': '1981-05-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1981-05-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.71, 'read_date': '1981-06-12', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.1, 'read_date': '1981-06-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.3, 'read_date': '1981-06-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.02, 'read_date': '1981-07-23', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.13, 'read_date': '1981-09-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.0, 'read_date': '1981-09-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.3, 'read_date': '1981-10-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.82, 'read_date': '1982-04-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.4, 'read_date': '1982-09-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.85, 'read_date': '1983-05-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 818.43, 'read_date': '1983-11-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.54, 'read_date': '1984-06-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.93, 'read_date': '1985-06-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.59, 'read_date': '1997-04-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.59, 'read_date': '1997-04-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.55, 'read_date': '1997-04-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.49, 'read_date': '1997-04-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.49, 'read_date': '1997-05-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.45, 'read_date': '1997-05-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.44, 'read_date': '1997-05-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.42, 'read_date': '1997-05-12', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.34, 'read_date': '1997-05-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.3, 'read_date': '1997-05-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.23, 'read_date': '1997-05-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.22, 'read_date': '1997-06-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.15, 'read_date': '1997-06-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.03, 'read_date': '1997-06-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.03, 'read_date': '1997-06-25', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.18, 'read_date': '1997-06-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.74, 'read_date': '1997-07-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.11, 'read_date': '1997-07-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.39, 'read_date': '1997-07-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.31, 'read_date': '1997-07-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.19, 'read_date': '1997-07-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.23, 'read_date': '1997-07-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.19, 'read_date': '1997-07-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.26, 'read_date': '1997-07-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.5, 'read_date': '1997-07-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.34, 'read_date': '1997-07-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.24, 'read_date': '1997-07-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.42, 'read_date': '1997-07-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.02, 'read_date': '1997-07-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.67, 'read_date': '1997-07-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.87, 'read_date': '1997-07-23', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.49, 'read_date': '1997-07-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.23, 'read_date': '1997-07-31', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.19, 'read_date': '1997-08-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.21, 'read_date': '1997-08-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.14, 'read_date': '1997-08-10', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.11, 'read_date': '1997-08-12', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.23, 'read_date': '1997-08-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.8, 'read_date': '1997-08-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 816.13, 'read_date': '1997-08-20', 'datum_adj': 'NGVD 29'},
# ...
#   {'elevation': 815.46, 'read_date': '2002-11-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.41, 'read_date': '2002-11-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.51, 'read_date': '2003-04-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.69, 'read_date': '2003-04-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.7, 'read_date': '2003-04-23', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.63, 'read_date': '2003-04-30', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.59, 'read_date': '2003-05-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.22, 'read_date': '2003-05-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.34, 'read_date': '2003-05-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.39, 'read_date': '2003-05-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.42, 'read_date': '2003-06-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.35, 'read_date': '2003-06-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.25, 'read_date': '2003-06-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.01, 'read_date': '2003-06-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.55, 'read_date': '2003-06-25', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.15, 'read_date': '2003-07-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.13, 'read_date': '2003-07-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 815.06, 'read_date': '2003-07-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.92, 'read_date': '2003-07-23', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.76, 'read_date': '2003-07-30', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.6, 'read_date': '2003-08-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.47, 'read_date': '2003-08-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.38, 'read_date': '2003-08-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.22, 'read_date': '2003-08-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.02, 'read_date': '2003-09-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.87, 'read_date': '2003-09-10', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.9, 'read_date': '2003-09-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.82, 'read_date': '2003-09-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.67, 'read_date': '2003-10-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.58, 'read_date': '2003-10-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.54, 'read_date': '2003-10-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.46, 'read_date': '2003-10-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.36, 'read_date': '2003-10-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.32, 'read_date': '2003-11-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.24, 'read_date': '2003-11-12', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.22, 'read_date': '2003-11-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.24, 'read_date': '2003-11-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.07, 'read_date': '2004-04-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.97, 'read_date': '2004-04-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.15, 'read_date': '2004-04-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.13, 'read_date': '2004-04-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.97, 'read_date': '2004-05-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.99, 'read_date': '2004-05-12', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.11, 'read_date': '2004-05-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.25, 'read_date': '2004-05-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.36, 'read_date': '2004-05-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.59, 'read_date': '2004-06-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.75, 'read_date': '2004-06-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.85, 'read_date': '2004-06-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.75, 'read_date': '2004-06-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.71, 'read_date': '2004-06-23', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.61, 'read_date': '2004-06-30', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.63, 'read_date': '2004-07-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.65, 'read_date': '2004-07-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.73, 'read_date': '2004-07-12', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.65, 'read_date': '2004-07-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.55, 'read_date': '2004-07-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.43, 'read_date': '2004-07-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.39, 'read_date': '2004-07-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.41, 'read_date': '2004-08-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.25, 'read_date': '2004-08-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.05, 'read_date': '2004-08-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.1, 'read_date': '2004-08-25', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.05, 'read_date': '2004-09-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.02, 'read_date': '2004-09-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.27, 'read_date': '2004-09-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.17, 'read_date': '2004-09-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.09, 'read_date': '2004-09-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.98, 'read_date': '2004-10-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.92, 'read_date': '2004-10-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.83, 'read_date': '2004-10-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.79, 'read_date': '2004-10-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.95, 'read_date': '2004-11-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.89, 'read_date': '2004-11-10', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.8, 'read_date': '2004-11-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.83, 'read_date': '2004-11-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.76, 'read_date': '2004-12-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.76, 'read_date': '2005-04-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.77, 'read_date': '2005-04-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.89, 'read_date': '2005-04-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.8, 'read_date': '2005-04-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.7, 'read_date': '2005-05-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.69, 'read_date': '2005-05-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.82, 'read_date': '2005-05-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.79, 'read_date': '2005-05-25', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.77, 'read_date': '2005-06-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.82, 'read_date': '2005-06-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.82, 'read_date': '2005-06-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.83, 'read_date': '2005-06-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.87, 'read_date': '2005-06-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.75, 'read_date': '2005-07-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.63, 'read_date': '2005-07-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.46, 'read_date': '2005-07-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.28, 'read_date': '2005-07-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.45, 'read_date': '2005-08-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.5, 'read_date': '2005-08-10', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.48, 'read_date': '2005-08-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.4, 'read_date': '2005-08-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.44, 'read_date': '2005-08-31', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.54, 'read_date': '2005-09-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.58, 'read_date': '2005-09-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.54, 'read_date': '2005-09-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.6, 'read_date': '2005-09-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.48, 'read_date': '2005-10-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.52, 'read_date': '2005-10-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.7, 'read_date': '2005-10-12', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.63, 'read_date': '2005-10-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.56, 'read_date': '2005-10-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.48, 'read_date': '2005-11-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.34, 'read_date': '2005-11-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.38, 'read_date': '2005-11-23', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.45, 'read_date': '2005-11-30', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.61, 'read_date': '2006-04-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.09, 'read_date': '2006-04-12', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.02, 'read_date': '2006-04-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.94, 'read_date': '2006-04-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.24, 'read_date': '2006-05-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.17, 'read_date': '2006-05-10', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.09, 'read_date': '2006-05-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.09, 'read_date': '2006-05-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.07, 'read_date': '2006-05-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.01, 'read_date': '2006-05-31', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.94, 'read_date': '2006-06-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.89, 'read_date': '2006-06-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.75, 'read_date': '2006-06-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.85, 'read_date': '2006-06-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.77, 'read_date': '2006-06-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.6, 'read_date': '2006-07-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.41, 'read_date': '2006-07-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.27, 'read_date': '2006-07-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.33, 'read_date': '2006-07-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.71, 'read_date': '2006-08-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.61, 'read_date': '2006-08-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.53, 'read_date': '2006-08-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.53, 'read_date': '2006-08-23', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.58, 'read_date': '2006-08-30', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.58, 'read_date': '2006-09-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.45, 'read_date': '2006-09-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.35, 'read_date': '2006-09-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.37, 'read_date': '2006-09-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.29, 'read_date': '2006-10-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.13, 'read_date': '2006-10-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.07, 'read_date': '2006-10-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.97, 'read_date': '2006-10-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.89, 'read_date': '2006-11-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.87, 'read_date': '2006-11-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.79, 'read_date': '2006-11-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.75, 'read_date': '2006-11-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.73, 'read_date': '2006-11-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.9, 'read_date': '2007-03-28', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.11, 'read_date': '2007-04-04', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.17, 'read_date': '2007-04-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.05, 'read_date': '2007-04-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.05, 'read_date': '2007-04-25', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.95, 'read_date': '2007-05-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.93, 'read_date': '2007-05-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.87, 'read_date': '2007-05-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.7, 'read_date': '2007-05-23', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.71, 'read_date': '2007-05-30', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.69, 'read_date': '2007-06-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.51, 'read_date': '2007-06-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.45, 'read_date': '2007-06-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.45, 'read_date': '2007-06-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.29, 'read_date': '2007-07-03', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.25, 'read_date': '2007-07-11', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.15, 'read_date': '2007-07-18', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.2, 'read_date': '2007-07-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.12, 'read_date': '2007-07-25', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.01, 'read_date': '2007-08-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 811.91, 'read_date': '2007-08-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.43, 'read_date': '2007-08-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.79, 'read_date': '2007-08-21', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.99, 'read_date': '2007-08-27', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.82, 'read_date': '2007-09-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.87, 'read_date': '2007-09-10', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.69, 'read_date': '2007-09-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.42, 'read_date': '2007-09-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.59, 'read_date': '2007-10-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.01, 'read_date': '2007-10-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.93, 'read_date': '2007-10-15', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.19, 'read_date': '2007-10-22', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.16, 'read_date': '2007-10-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.01, 'read_date': '2007-11-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.97, 'read_date': '2007-11-13', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.91, 'read_date': '2007-11-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.81, 'read_date': '2007-11-26', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.95, 'read_date': '2008-04-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.93, 'read_date': '2008-05-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.21, 'read_date': '2008-05-07', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.15, 'read_date': '2008-05-16', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.05, 'read_date': '2008-05-20', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.87, 'read_date': '2008-05-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.89, 'read_date': '2008-06-02', 'datum_adj': 'NGVD 29'},
#   {'elevation': 814.0, 'read_date': '2008-06-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.91, 'read_date': '2008-06-17', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.91, 'read_date': '2008-06-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.71, 'read_date': '2008-06-30', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.57, 'read_date': '2008-07-08', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.29, 'read_date': '2008-07-23', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.23, 'read_date': '2008-07-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.1, 'read_date': '2008-08-06', 'datum_adj': 'NGVD 29'},
#   {'elevation': 813.01, 'read_date': '2008-08-14', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.99, 'read_date': '2008-08-29', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.83, 'read_date': '2008-09-05', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.79, 'read_date': '2008-09-12', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.75, 'read_date': '2008-09-19', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.71, 'read_date': '2008-09-24', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.59, 'read_date': '2008-10-01', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.63, 'read_date': '2008-10-09', 'datum_adj': 'NGVD 29'},
#   {'elevation': 812.59, 'read_date': '2008-10-17', 'datum_adj': 'NGVD 29'},
#   ...]}
